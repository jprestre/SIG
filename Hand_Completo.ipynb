# %% [markdown]
# ## Calcular el Hand Completo para toda una zona

# %%
# ------------------------------------------------------------------------------------------------------------------
# Funcion para crear raster a partir de un array

# Importar todas las  librerías
def array2raster(newRasterfn,rasterOrigin,pixelWidth,pixelHeight,array):

    import gdal, ogr, os, osr
    
    cols = array.shape[1]
    rows = array.shape[0]
    originX = rasterOrigin[0]
    originY = rasterOrigin[1]

    driver = gdal.GetDriverByName('GTiff')
    outRaster = driver.Create(newRasterfn, cols, rows, 1, gdal.GDT_Int16, ['COMPRESS=DEFLATE','PREDICTOR=2','ZLEVEL=1'])
    outRaster.SetGeoTransform((originX, pixelWidth, 0, originY, 0, pixelHeight))
    outband = outRaster.GetRasterBand(1)
    outband.SetNoDataValue(-9999.)  #ensayo
    outband.WriteArray(array)
    outRasterSRS = osr.SpatialReference()
    outRasterSRS.ImportFromEPSG(4326)
    outRaster.SetProjection(outRasterSRS.ExportToWkt())
    outband.FlushCache()

# %%
# Importar todas las  librerías

from osgeo import gdal, gdalconst
from pysheds.grid import Grid
import numpy as np
import fnmatch
import glob, os
import shutil
import re
import rasterio
from rasterio.merge import merge
from rasterio.plot import show
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %%
# %%time

Pais = 'Mexico'

# Coordenadas del dominio espacial que abarca todas las planchas que componen la región de interés.
# Lat_infer_izq, Lon_infer_izq, Lat_sup_der, Lon_sup_der 

dominio = '22,-107,32,-97'
hand_name = 'HAND_N22W107_N32W97'

# Extension del archivo que contiene los datos del DEM. Puede ser Tiff, o bil, o ascii, o cualquier formato de estos
extension = 'bil'

# Tamaño del pixel de salida del HAND. Se entra argumento para remuestrear y hacer la salida menos pesada para el
# procesamiento
size_pixel = 200


# ------------------------------------------------------------------------------------------------------------------
# Preparar los directorios de trabajo

# Ruta absoluta donde están guardados los dems que bajamos para toda la región del USGS. A menos que se quiera
#  procesar una región diferente a las planchas descargadas, este debería quedar por defecto
path_dems = '/opt/geociencia/coreclima/Compartidos/HAND_Region/Procesamiento_DEMs_prueba/1.DEMs_unzip/'

out_ruta = '/opt/geociencia/coreclima/Compartidos/HAND_Region/' + Pais + '/'

if not os.path.isdir(out_ruta):
    try:
        os.mkdir(out_ruta)
    except OSError:
        print ("Creation of the directory %s failed" % out_ruta)
    else:
        print ("Successfully created the directory %s " % out_ruta)    


# ------------------------------------------------------------------------------------------------------------------        
# Preprarar la lista con el nombre de los archivos del dominio a procesar

dominio = list(map(float, dominio.split(',')))
os.chdir(path_dems)
file_list = list()
for file in glob.glob('*.' + extension):
    file_list.append(file)
file_list.sort()

processlist = list()

for file in file_list:
    coord = re.findall(r'(\d+)_',file)
    coord = list(map(int, coord))
    lat = re.findall(r'(.)\d+_',file)[0]
    if lat == 's':
        coord[0]=-coord[0]
        
    if (dominio[0]-1 <= coord[0] <= dominio[2]+1 and dominio[1]-1 <= -coord[1] <= dominio[3]+1):
        processlist.append(file)
        

# ------------------------------------------------------------------------------------------------------------------
# Remuestrear los raster del dominio de interés para bajar resolución espacial

for file in processlist:

    inputfile = path_dems+'/'+file
    input_ = gdal.Open(inputfile, gdalconst.GA_ReadOnly)
    inputProj = input_.GetProjection()
    inputTrans = input_.GetGeoTransform()
    bandinput = input_.GetRasterBand(1)  

    # Tamaño de celda en raster original (metros)
    cell_size=inputTrans[1]*111100
    # factor de relación entre tamaño viejo y tamaño nuevo
    factor = int(cell_size)/size_pixel
    f1 = factor*input_.RasterXSize
    ncell = int(f1)
    # factor corregido
    factor_corr = ncell/input_.RasterXSize
    # Resultado
    res = inputTrans[1]/factor_corr

    inputTrans = list(inputTrans)
    inputTrans[1] = res
    inputTrans[-1] = -res
    referenceTrans = tuple(inputTrans)
    x = ncell
    y = ncell


    bandreference = bandinput
    referenceProj = inputProj

    outputfile = out_ruta+file[:-4]+'_resize.tif'
    driver= gdal.GetDriverByName('GTiff')
    output = driver.Create(outputfile,x,y,1,bandreference.DataType)
    output.SetGeoTransform(referenceTrans)
    output.SetProjection(referenceProj)

    gdal.ReprojectImage(input_,output,inputProj,referenceProj,gdalconst.GRA_Bilinear)
    del output

# %%
# ------------------------------------------------------------------------------------------------------------------
# Hacer el merge de todos los raster remuestreados que quedaron dentro del dominio especificado

search_criteria = "*_resize.tif"
q = os.path.join(out_ruta, search_criteria)
dem_fps = glob.glob(q)

src_files_to_mosaic = []
for fp in dem_fps:
    src = rasterio.open(fp)
    src_files_to_mosaic.append(src)

    
mosaic, out_trans = merge(src_files_to_mosaic)

GT_ET=[out_trans.c, out_trans.a, out_trans.b, out_trans.f, out_trans.d, out_trans.e]

# Guardar el Hand como raster
# GT_ET = inputTrans 
rasterOrigin = (GT_ET[0],GT_ET[3])
pixelWidth = GT_ET[1]
pixelHeight = GT_ET[-1]
newRasterfn = out_ruta+'Resize_completo.tif'
array = mosaic[0,:,:] 
array2raster(newRasterfn,rasterOrigin,pixelWidth,pixelHeight,array)

for i in dem_fps:
    os.remove(i)

# %%
# %%time
# ------------------------------------------------------------------------------------------------------------------
# Estimar el HAND del dominio especificado a partir de Pysheds


# Cargar el DEM
grid = Grid.from_raster(out_ruta+'Resize_completo.tif', data_name='dem')
# Fill depressions in DEM
grid.fill_depressions('dem', out_name='flooded_dem')
# Resolve flats in DEM
grid.resolve_flats('flooded_dem', out_name='inflated_dem')
# Specify directional mapping
dirmap = (64, 128, 1, 2, 4, 8, 16, 32)
# Compute flow directions
grid.flowdir(data='inflated_dem', out_name='dir', dirmap=dirmap)
# Calculate flow accumulation
grid.accumulation(data='dir', dirmap=dirmap, out_name='acc')
# Calcula la red de drenaje
R_drain    = grid.view('acc')
R_drain[R_drain<1000]  = 0
R_drain[R_drain>=1000] = 1
# Calcular Hand
grid.compute_hand('dir', 'dem', R_drain, out_name='hand')
grid.hand[grid.hand<0]  = 0

os.remove(out_ruta+'Resize_completo.tif')

# %%
# ------------------------------------------------------------------------------------------------------------------
# Guardar el HAND recortandolo para que no quede con los bordes comidos

rasterOrigin = (GT_ET[0],GT_ET[3])
pixelWidth = GT_ET[1]
pixelHeight = GT_ET[-1]
newRasterfn = out_ruta+'HAND_completo.tif'
array = grid.hand
array2raster(newRasterfn,rasterOrigin,pixelWidth,pixelHeight,array)

# %%
projwin = [dominio[1],dominio[2],dominio[3],dominio[0]]

translateoptions = gdal.TranslateOptions(
    gdal.ParseCommandLine('-co COMPRESS=DEFLATE -co PREDICTOR=2 -co ZLEVEL=1'), projWin = projwin)

ds = gdal.Open(out_ruta+'HAND_completo.tif')
ds = gdal.Translate(out_ruta+hand_name+'.tif', ds, options=translateoptions)
ds = None

os.remove(out_ruta+'HAND_completo.tif')

# %%
# -------------------------------------------------------------------------------------------------------------------
# Hacer el merge de las planchas hand procesadas. Solo se ejecuta al final cuando se tengan listos todos los
# dominios que integran el país o la región de estudio

search_criteria = "*.tif"
q = os.path.join(out_ruta, search_criteria)
dem_fps = glob.glob(q)

src_files_to_mosaic = []
for fp in dem_fps:
    src = rasterio.open(fp)
    src_files_to_mosaic.append(src)

    
mosaic, out_trans = merge(src_files_to_mosaic)

GT_ET=[out_trans.c, out_trans.a, out_trans.b, out_trans.f, out_trans.d, out_trans.e]

# Guardar el Hand como raster
# GT_ET = inputTrans 
rasterOrigin = (GT_ET[0],GT_ET[3])
pixelWidth = GT_ET[1]
pixelHeight = GT_ET[-1]
newRasterfn = out_ruta + Pais + str(size_pixel) +'m_Python.tif'
array = mosaic[0,:,:] 
array2raster(newRasterfn,rasterOrigin,pixelWidth,pixelHeight,array)

# %% [markdown]
# ##  Integrado todo algoritmo para sudamerica 200m

# %%
# ------------------------------------------------------------------------------------------------------------------
# Funcion para crear raster a partir de un array

# Importar todas las  librerías
def array2raster(newRasterfn,rasterOrigin,pixelWidth,pixelHeight,array):

    import gdal, ogr, os, osr
    
    cols = array.shape[1]
    rows = array.shape[0]
    originX = rasterOrigin[0]
    originY = rasterOrigin[1]

    driver = gdal.GetDriverByName('GTiff')
    outRaster = driver.Create(newRasterfn, cols, rows, 1, gdal.GDT_Int16, ['COMPRESS=DEFLATE','PREDICTOR=2','ZLEVEL=1'])
    outRaster.SetGeoTransform((originX, pixelWidth, 0, originY, 0, pixelHeight))
    outband = outRaster.GetRasterBand(1)
    outband.SetNoDataValue(-9999.)  #ensayo
    outband.WriteArray(array)
    outRasterSRS = osr.SpatialReference()
    outRasterSRS.ImportFromEPSG(4326)
    outRaster.SetProjection(outRasterSRS.ExportToWkt())
    outband.FlushCache()
    
# Importar todas las  librerías

from osgeo import gdal, gdalconst
from pysheds.grid import Grid
import numpy as np
import fnmatch
import glob, os
import shutil
import re
import rasterio
from rasterio.merge import merge
from rasterio.plot import show
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# Extension del archivo que contiene los datos del DEM. Puede ser Tiff, o bil, o ascii, o cualquier formato de estos
extension = 'bil'

# Tamaño del pixel de salida del HAND. Se entra argumento para remuestrear y hacer la salida menos pesada para el
# procesamiento
size_pixel = 200

Pais = 'America'


# ------------------------------------------------------------------------------------------------------------------
# Preparar los directorios de trabajo

# Ruta absoluta donde están guardados los dems que bajamos para toda la región del USGS. A menos que se quiera
#  procesar una región diferente a las planchas descargadas, este debería quedar por defecto
path_dems = '/opt/geociencia/coreclima/Compartidos/HAND_Region/Procesamiento_DEMs_prueba/1.DEMs_unzip/'

out_ruta = '/opt/geociencia/coreclima/Compartidos/HAND_Region/' + Pais + '/'

if not os.path.isdir(out_ruta):
    try:
        os.mkdir(out_ruta)
    except OSError:
        print ("Creation of the directory %s failed" % out_ruta)
    else:
        print ("Successfully created the directory %s " % out_ruta)    



# Coordenadas del dominio espacial que abarca todas las planchas que componen la región de interés.
# Lat_infer_izq, Lon_infer_izq, Lat_sup_der, Lon_sup_der 
# Leer los dominios a procesar
Path = '/opt/geociencia/coreclima/Compartidos/HAND_Region/'
file = 'Regiones_200m.csv'

dominios = np.genfromtxt(Path + file, delimiter = ';', skip_header=1)

def sign(s):
    if s < 0:
        lat_ = 'S'
    else:
        lat_ = 'N'
    return lat_

for i in range(len(dominios)):
    coords = list(dominios[i][1:])
    string_coord = [str(cord) for cord in coords]
    dominio = ",".join(string_coord)
    hand_name = 'HAND_'+sign(coords[0])+str(round(coords[0]))+'W'+str(abs(round(coords[1])))+'_'+sign(coords[2])+str(round(coords[2]))+'W'+str(abs(round(coords[3])))

    # ------------------------------------------------------------------------------------------------------------------        
    # Preprarar la lista con el nombre de los archivos del dominio a procesar

    dominio = list(map(float, dominio.split(',')))
    os.chdir(path_dems)
    file_list = list()
    for file in glob.glob('*.' + extension):
        file_list.append(file)
    file_list.sort()

    processlist = list()

    for file in file_list:
        coord = re.findall(r'(\d+)_',file)
        coord = list(map(int, coord))
        lat = re.findall(r'(.)\d+_',file)[0]
        if lat == 's':
            coord[0]=-coord[0]

        if (dominio[0]-1 <= coord[0] <= dominio[2]+1 and dominio[1]-1 <= -coord[1] <= dominio[3]+1):
            processlist.append(file)


    # ------------------------------------------------------------------------------------------------------------------
    # Remuestrear los raster del dominio de interés para bajar resolución espacial

    for file in processlist:

        inputfile = path_dems+'/'+file
        input_ = gdal.Open(inputfile, gdalconst.GA_ReadOnly)
        inputProj = input_.GetProjection()
        inputTrans = input_.GetGeoTransform()
        bandinput = input_.GetRasterBand(1)  

        # Tamaño de celda en raster original (metros)
        cell_size=inputTrans[1]*111100
        # factor de relación entre tamaño viejo y tamaño nuevo
        factor = int(cell_size)/size_pixel
        f1 = factor*input_.RasterXSize
        ncell = int(f1)
        # factor corregido
        factor_corr = ncell/input_.RasterXSize
        # Resultado
        res = inputTrans[1]/factor_corr

        inputTrans = list(inputTrans)
        inputTrans[1] = res
        inputTrans[-1] = -res
        referenceTrans = tuple(inputTrans)
        x = ncell
        y = ncell


        bandreference = bandinput
        referenceProj = inputProj

        outputfile = out_ruta+file[:-4]+'_resize.tif'
        driver= gdal.GetDriverByName('GTiff')
        output = driver.Create(outputfile,x,y,1,bandreference.DataType)
        output.SetGeoTransform(referenceTrans)
        output.SetProjection(referenceProj)

        gdal.ReprojectImage(input_,output,inputProj,referenceProj,gdalconst.GRA_Bilinear)
        del output



    # ------------------------------------------------------------------------------------------------------------------
    # Hacer el merge de todos los raster remuestreados que quedaron dentro del dominio especificado

    search_criteria = "*_resize.tif"
    q = os.path.join(out_ruta, search_criteria)
    dem_fps = glob.glob(q)

    src_files_to_mosaic = []
    for fp in dem_fps:
        src = rasterio.open(fp)
        src_files_to_mosaic.append(src)


    mosaic, out_trans = merge(src_files_to_mosaic)

    GT_ET=[out_trans.c, out_trans.a, out_trans.b, out_trans.f, out_trans.d, out_trans.e]

    # Guardar el Hand como raster
    # GT_ET = inputTrans 
    rasterOrigin = (GT_ET[0],GT_ET[3])
    pixelWidth = GT_ET[1]
    pixelHeight = GT_ET[-1]
    newRasterfn = out_ruta+'Resize_completo.tif'
    array = mosaic[0,:,:] 
    array2raster(newRasterfn,rasterOrigin,pixelWidth,pixelHeight,array)

    for i in dem_fps:
        os.remove(i)


    # ------------------------------------------------------------------------------------------------------------------
    # Estimar el HAND del dominio especificado a partir de Pysheds


    # Cargar el DEM
    grid = Grid.from_raster(out_ruta+'Resize_completo.tif', data_name='dem')
    # Fill depressions in DEM
    grid.fill_depressions('dem', out_name='flooded_dem')
    # Resolve flats in DEM
    grid.resolve_flats('flooded_dem', out_name='inflated_dem')
    # Specify directional mapping
    dirmap = (64, 128, 1, 2, 4, 8, 16, 32)
    # Compute flow directions
    grid.flowdir(data='inflated_dem', out_name='dir', dirmap=dirmap)
    # Calculate flow accumulation
    grid.accumulation(data='dir', dirmap=dirmap, out_name='acc')
    # Calcula la red de drenaje
    R_drain    = grid.view('acc')
    R_drain[R_drain<1000]  = 0
    R_drain[R_drain>=1000] = 1
    # Calcular Hand
    grid.compute_hand('dir', 'dem', R_drain, out_name='hand')
    grid.hand[grid.hand<0]  = 0

    os.remove(out_ruta+'Resize_completo.tif')

    # ------------------------------------------------------------------------------------------------------------------
    # Guardar el HAND recortandolo para que no quede con los bordes comidos

    rasterOrigin = (GT_ET[0],GT_ET[3])
    pixelWidth = GT_ET[1]
    pixelHeight = GT_ET[-1]
    newRasterfn = out_ruta+'HAND_completo.tif'
    array = grid.hand
    array2raster(newRasterfn,rasterOrigin,pixelWidth,pixelHeight,array)

    projwin = [dominio[1],dominio[2],dominio[3],dominio[0]]

    translateoptions = gdal.TranslateOptions(
        gdal.ParseCommandLine('-co COMPRESS=DEFLATE -co PREDICTOR=2 -co ZLEVEL=1'), projWin = projwin)

    ds = gdal.Open(out_ruta+'HAND_completo.tif')
    ds = gdal.Translate(out_ruta+hand_name+'.tif', ds, options=translateoptions)
    ds = None

    os.remove(out_ruta+'HAND_completo.tif')

# %%
# -------------------------------------------------------------------------------------------------------------------
# Hacer el merge de las planchas hand procesadas. Solo se ejecuta al final cuando se tengan listos todos los
# dominios que integran el país o la región de estudio

search_criteria = "*.tif"
q = os.path.join(out_ruta, search_criteria)
dem_fps = glob.glob(q)

src_files_to_mosaic = []
for fp in dem_fps:
    src = rasterio.open(fp)
    src_files_to_mosaic.append(src)

    
mosaic, out_trans = merge(src_files_to_mosaic)

GT_ET=[out_trans.c, out_trans.a, out_trans.b, out_trans.f, out_trans.d, out_trans.e]

# Guardar el Hand como raster
# GT_ET = inputTrans 
rasterOrigin = (GT_ET[0],GT_ET[3])
pixelWidth = GT_ET[1]
pixelHeight = GT_ET[-1]
newRasterfn = out_ruta + Pais + str(size_pixel) +'m_Python.tif'
array = mosaic[0,:,:] 
array2raster(newRasterfn,rasterOrigin,pixelWidth,pixelHeight,array)

# %%
file_list
# Out:
# ['n00_w050_1arc_v3.bil',
#  'n00_w051_1arc_v3.bil',
#  'n00_w052_1arc_v3.bil',
#  'n00_w053_1arc_v3.bil',
#  'n00_w054_1arc_v3.bil',
#  'n00_w055_1arc_v3.bil',
#  'n00_w056_1arc_v3.bil',
#  'n00_w057_1arc_v3.bil',
#  'n00_w058_1arc_v3.bil',
#  'n00_w059_1arc_v3.bil',
#  'n00_w060_1arc_v3.bil',
#  'n00_w061_1arc_v3.bil',
#  'n00_w062_1arc_v3.bil',
#  'n00_w063_1arc_v3.bil',
#  'n00_w064_1arc_v3.bil',
#  'n00_w065_1arc_v3.bil',
#  'n00_w066_1arc_v3.bil',
#  'n00_w067_1arc_v3.bil',
#  'n00_w068_1arc_v3.bil',
#  'n00_w069_1arc_v3.bil',
#  'n00_w070_1arc_v3.bil',
#  'n00_w071_1arc_v3.bil',
#  'n00_w072_1arc_v3.bil',
#  'n00_w073_1arc_v3.bil',
#  'n00_w074_1arc_v3.bil',
#  'n00_w075_1arc_v3.bil',
#  'n00_w076_1arc_v3.bil',
#  'n00_w077_1arc_v3.bil',
#  'n00_w078_1arc_v3.bil',
#  'n00_w079_1arc_v3.bil',
#  'n00_w080_1arc_v3.bil',
#  'n00_w081_1arc_v3.bil',
#  'n01_w050_1arc_v3.bil',
#  'n01_w051_1arc_v3.bil',
#  'n01_w052_1arc_v3.bil',
#  'n01_w053_1arc_v3.bil',
#  'n01_w054_1arc_v3.bil',
#  'n01_w055_1arc_v3.bil',
#  'n01_w056_1arc_v3.bil',
#  'n01_w057_1arc_v3.bil',
#  'n01_w058_1arc_v3.bil',
#  'n01_w059_1arc_v3.bil',
#  'n01_w060_1arc_v3.bil',
#  'n01_w061_1arc_v3.bil',
#  'n01_w062_1arc_v3.bil',
#  'n01_w063_1arc_v3.bil',
#  'n01_w064_1arc_v3.bil',
#  'n01_w065_1arc_v3.bil',
#  'n01_w066_1arc_v3.bil',
#  'n01_w067_1arc_v3.bil',
#  'n01_w068_1arc_v3.bil',
#  'n01_w069_1arc_v3.bil',
#  'n01_w070_1arc_v3.bil',
#  'n01_w071_1arc_v3.bil',
#  'n01_w072_1arc_v3.bil',
#  'n01_w073_1arc_v3.bil',
#  'n01_w074_1arc_v3.bil',
#  'n01_w075_1arc_v3.bil',
#  'n01_w076_1arc_v3.bil',
#  'n01_w077_1arc_v3.bil',
#  'n01_w078_1arc_v3.bil',
#  'n01_w079_1arc_v3.bil',
#  'n01_w080_1arc_v3.bil',
#  'n02_w051_1arc_v3.bil',
#  'n02_w052_1arc_v3.bil',
#  'n02_w053_1arc_v3.bil',
#  'n02_w054_1arc_v3.bil',
#  'n02_w055_1arc_v3.bil',
#  'n02_w056_1arc_v3.bil',
#  'n02_w057_1arc_v3.bil',
#  'n02_w058_1arc_v3.bil',
#  'n02_w059_1arc_v3.bil',
#  'n02_w060_1arc_v3.bil',
#  'n02_w061_1arc_v3.bil',
#  'n02_w062_1arc_v3.bil',
#  'n02_w063_1arc_v3.bil',
#  'n02_w064_1arc_v3.bil',
#  'n02_w065_1arc_v3.bil',
#  'n02_w066_1arc_v3.bil',
#  'n02_w067_1arc_v3.bil',
#  'n02_w068_1arc_v3.bil',
#  'n02_w069_1arc_v3.bil',
#  'n02_w070_1arc_v3.bil',
#  'n02_w071_1arc_v3.bil',
#  'n02_w072_1arc_v3.bil',
#  'n02_w073_1arc_v3.bil',
#  'n02_w074_1arc_v3.bil',
#  'n02_w075_1arc_v3.bil',
#  'n02_w076_1arc_v3.bil',
#  'n02_w077_1arc_v3.bil',
#  'n02_w078_1arc_v3.bil',
#  'n02_w079_1arc_v3.bil',
#  'n03_w051_1arc_v3.bil',
#  'n03_w052_1arc_v3.bil',
#  'n03_w053_1arc_v3.bil',
#  'n03_w054_1arc_v3.bil',
#  'n03_w055_1arc_v3.bil',
#  'n03_w056_1arc_v3.bil',
#  'n03_w057_1arc_v3.bil',
#  'n03_w058_1arc_v3.bil',
#  'n03_w059_1arc_v3.bil',
#  'n03_w060_1arc_v3.bil',
#  'n03_w061_1arc_v3.bil',
#  'n03_w062_1arc_v3.bil',
#  'n03_w063_1arc_v3.bil',
#  'n03_w064_1arc_v3.bil',
#  'n03_w065_1arc_v3.bil',
#  'n03_w066_1arc_v3.bil',
#  'n03_w067_1arc_v3.bil',
#  'n03_w068_1arc_v3.bil',
#  'n03_w069_1arc_v3.bil',
#  'n03_w070_1arc_v3.bil',
#  'n03_w071_1arc_v3.bil',
#  'n03_w072_1arc_v3.bil',
#  'n03_w073_1arc_v3.bil',
#  'n03_w074_1arc_v3.bil',
#  'n03_w075_1arc_v3.bil',
#  'n03_w076_1arc_v3.bil',
#  'n03_w077_1arc_v3.bil',
#  'n03_w078_1arc_v3.bil',
#  'n03_w079_1arc_v3.bil',
#  'n03_w082_1arc_v3.bil',
#  'n04_w052_1arc_v3.bil',
#  'n04_w053_1arc_v3.bil',
#  'n04_w054_1arc_v3.bil',
#  'n04_w055_1arc_v3.bil',
#  'n04_w056_1arc_v3.bil',
#  'n04_w057_1arc_v3.bil',
#  'n04_w058_1arc_v3.bil',
#  'n04_w059_1arc_v3.bil',
#  'n04_w060_1arc_v3.bil',
#  'n04_w061_1arc_v3.bil',
#  'n04_w062_1arc_v3.bil',
#  'n04_w063_1arc_v3.bil',
#  'n04_w064_1arc_v3.bil',
#  'n04_w065_1arc_v3.bil',
#  'n04_w066_1arc_v3.bil',
#  'n04_w067_1arc_v3.bil',
#  'n04_w068_1arc_v3.bil',
#  'n04_w069_1arc_v3.bil',
#  'n04_w070_1arc_v3.bil',
#  'n04_w071_1arc_v3.bil',
#  'n04_w072_1arc_v3.bil',
#  'n04_w073_1arc_v3.bil',
#  'n04_w074_1arc_v3.bil',
#  'n04_w075_1arc_v3.bil',
#  'n04_w076_1arc_v3.bil',
#  'n04_w077_1arc_v3.bil',
#  'n04_w078_1arc_v3.bil',
#  'n04_w082_1arc_v3.bil',
#  'n05_w053_1arc_v3.bil',
#  'n05_w054_1arc_v3.bil',
#  'n05_w055_1arc_v3.bil',
#  'n05_w056_1arc_v3.bil',
#  'n05_w057_1arc_v3.bil',
#  'n05_w058_1arc_v3.bil',
#  'n05_w059_1arc_v3.bil',
#  'n05_w060_1arc_v3.bil',
#  'n05_w061_1arc_v3.bil',
#  'n05_w062_1arc_v3.bil',
#  'n05_w063_1arc_v3.bil',
#  'n05_w064_1arc_v3.bil',
#  'n05_w065_1arc_v3.bil',
#  'n05_w066_1arc_v3.bil',
#  'n05_w067_1arc_v3.bil',
#  'n05_w068_1arc_v3.bil',
#  'n05_w069_1arc_v3.bil',
#  'n05_w070_1arc_v3.bil',
#  'n05_w071_1arc_v3.bil',
#  'n05_w072_1arc_v3.bil',
#  'n05_w073_1arc_v3.bil',
#  'n05_w074_1arc_v3.bil',
#  'n05_w075_1arc_v3.bil',
#  'n05_w076_1arc_v3.bil',
#  'n05_w077_1arc_v3.bil',
#  'n05_w078_1arc_v3.bil',
#  'n06_w056_1arc_v3.bil',
#  'n06_w057_1arc_v3.bil',
#  'n06_w058_1arc_v3.bil',
#  'n06_w059_1arc_v3.bil',
#  'n06_w060_1arc_v3.bil',
#  'n06_w061_1arc_v3.bil',
#  'n06_w062_1arc_v3.bil',
#  'n06_w063_1arc_v3.bil',
#  'n06_w064_1arc_v3.bil',
#  'n06_w065_1arc_v3.bil',
#  'n06_w066_1arc_v3.bil',
#  'n06_w067_1arc_v3.bil',
#  'n06_w068_1arc_v3.bil',
#  'n06_w069_1arc_v3.bil',
#  'n06_w070_1arc_v3.bil',
#  'n06_w071_1arc_v3.bil',
#  'n06_w072_1arc_v3.bil',
#  'n06_w073_1arc_v3.bil',
#  'n06_w074_1arc_v3.bil',
#  'n06_w075_1arc_v3.bil',
#  'n06_w076_1arc_v3.bil',
#  'n06_w077_1arc_v3.bil',
#  'n06_w078_1arc_v3.bil',
#  'n07_w059_1arc_v3.bil',
#  'n07_w060_1arc_v3.bil',
#  'n07_w061_1arc_v3.bil',
#  'n07_w062_1arc_v3.bil',
#  'n07_w063_1arc_v3.bil',
#  'n07_w064_1arc_v3.bil',
#  'n07_w065_1arc_v3.bil',
#  'n07_w066_1arc_v3.bil',
#  'n07_w067_1arc_v3.bil',
#  'n07_w068_1arc_v3.bil',
#  'n07_w069_1arc_v3.bil',
#  'n07_w070_1arc_v3.bil',
#  'n07_w071_1arc_v3.bil',
#  'n07_w072_1arc_v3.bil',
#  'n07_w073_1arc_v3.bil',
#  'n07_w074_1arc_v3.bil',
#  'n07_w075_1arc_v3.bil',
#  'n07_w076_1arc_v3.bil',
#  'n07_w077_1arc_v3.bil',
#  'n07_w078_1arc_v3.bil',
#  'n07_w079_1arc_v3.bil',
#  'n07_w080_1arc_v3.bil',
#  'n07_w081_1arc_v3.bil',
#  'n07_w082_1arc_v3.bil',
#  'n07_w083_1arc_v3.bil',
#  'n08_w060_1arc_v3.bil',
#  'n08_w061_1arc_v3.bil',
#  'n08_w062_1arc_v3.bil',
#  'n08_w063_1arc_v3.bil',
#  'n08_w064_1arc_v3.bil',
#  'n08_w065_1arc_v3.bil',
#  'n08_w066_1arc_v3.bil',
#  'n08_w067_1arc_v3.bil',
#  'n08_w068_1arc_v3.bil',
#  'n08_w069_1arc_v3.bil',
#  'n08_w070_1arc_v3.bil',
#  'n08_w071_1arc_v3.bil',
#  'n08_w072_1arc_v3.bil',
#  'n08_w073_1arc_v3.bil',
#  'n08_w074_1arc_v3.bil',
#  'n08_w075_1arc_v3.bil',
#  'n08_w076_1arc_v3.bil',
#  'n08_w077_1arc_v3.bil',
#  'n08_w078_1arc_v3.bil',
#  'n08_w079_1arc_v3.bil',
#  'n08_w080_1arc_v3.bil',
#  'n08_w081_1arc_v3.bil',
#  'n08_w082_1arc_v3.bil',
#  'n08_w083_1arc_v3.bil',
#  'n08_w084_1arc_v3.bil',
#  'n09_w061_1arc_v3.bil',
#  'n09_w062_1arc_v3.bil',
#  'n09_w063_1arc_v3.bil',
#  'n09_w064_1arc_v3.bil',
#  'n09_w065_1arc_v3.bil',
#  'n09_w066_1arc_v3.bil',
#  'n09_w067_1arc_v3.bil',
#  'n09_w068_1arc_v3.bil',
#  'n09_w069_1arc_v3.bil',
#  'n09_w070_1arc_v3.bil',
#  'n09_w071_1arc_v3.bil',
#  'n09_w072_1arc_v3.bil',
#  'n09_w073_1arc_v3.bil',
#  'n09_w074_1arc_v3.bil',
#  'n09_w075_1arc_v3.bil',
#  'n09_w076_1arc_v3.bil',
#  'n09_w077_1arc_v3.bil',
#  'n09_w078_1arc_v3.bil',
#  'n09_w079_1arc_v3.bil',
#  'n09_w080_1arc_v3.bil',
#  'n09_w081_1arc_v3.bil',
#  'n09_w082_1arc_v3.bil',
#  'n09_w083_1arc_v3.bil',
#  'n09_w084_1arc_v3.bil',
#  'n10_w061_1arc_v3.bil',
#  'n10_w062_1arc_v3.bil',
#  'n10_w063_1arc_v3.bil',
#  'n10_w064_1arc_v3.bil',
#  'n10_w065_1arc_v3.bil',
#  'n10_w066_1arc_v3.bil',
#  'n10_w067_1arc_v3.bil',
#  'n10_w068_1arc_v3.bil',
#  'n10_w069_1arc_v3.bil',
#  'n10_w070_1arc_v3.bil',
#  'n10_w071_1arc_v3.bil',
#  'n10_w072_1arc_v3.bil',
#  'n10_w073_1arc_v3.bil',
#  'n10_w074_1arc_v3.bil',
#  'n10_w075_1arc_v3.bil',
#  'n10_w076_1arc_v3.bil',
#  'n10_w084_1arc_v3.bil',
#  'n11_w061_1arc_v3.bil',
#  'n11_w062_1arc_v3.bil',
#  'n11_w064_1arc_v3.bil',
#  'n11_w065_1arc_v3.bil',
#  'n11_w067_1arc_v3.bil',
#  'n11_w068_1arc_v3.bil',
#  'n11_w069_1arc_v3.bil',
#  'n11_w070_1arc_v3.bil',
#  'n11_w071_1arc_v3.bil',
#  'n11_w072_1arc_v3.bil',
#  'n11_w073_1arc_v3.bil',
#  'n11_w074_1arc_v3.bil',
#  'n11_w075_1arc_v3.bil',
#  'n11_w084_1arc_v3.bil',
#  'n12_w062_1arc_v3.bil',
#  'n12_w069_1arc_v3.bil',
#  'n12_w070_1arc_v3.bil',
#  'n12_w071_1arc_v3.bil',
#  'n12_w072_1arc_v3.bil',
#  'n12_w073_1arc_v3.bil',
#  'n12_w082_1arc_v3.bil',
#  'n12_w083_1arc_v3.bil',
#  'n12_w084_1arc_v3.bil',
#  'n12_w087_1arc_v3.bil',
#  'n12_w088_1arc_v3.bil',
#  'n13_w060_1arc_v3.bil',
#  'n13_w061_1arc_v3.bil',
#  'n13_w062_1arc_v3.bil',
#  'n13_w081_1arc_v3.bil',
#  'n13_w082_1arc_v3.bil',
#  'n13_w084_1arc_v3.bil',
#  'n13_w085_1arc_v3.bil',
#  'n13_w086_1arc_v3.bil',
#  'n13_w087_1arc_v3.bil',
#  'n13_w088_1arc_v3.bil',
#  'n13_w089_1arc_v3.bil',
#  'n13_w090_1arc_v3.bil',
#  'n13_w091_1arc_v3.bil',
#  'n13_w092_1arc_v3.bil',
#  'n14_w061_1arc_v3.bil',
#  'n14_w062_1arc_v3.bil',
#  'n14_w081_1arc_v3.bil',
#  'n14_w083_1arc_v3.bil',
#  'n14_w084_1arc_v3.bil',
#  'n14_w085_1arc_v3.bil',
#  'n14_w086_1arc_v3.bil',
#  'n14_w087_1arc_v3.bil',
#  'n14_w088_1arc_v3.bil',
#  'n14_w089_1arc_v3.bil',
#  'n14_w090_1arc_v3.bil',
#  'n14_w091_1arc_v3.bil',
#  'n14_w092_1arc_v3.bil',
#  'n14_w093_1arc_v3.bil',
#  'n15_w062_1arc_v3.bil',
#  'n15_w064_1arc_v3.bil',
#  'n15_w079_1arc_v2.bil',
#  'n15_w079_1arc_v3.bil',
#  'n15_w080_1arc_v2.bil',
#  'n15_w080_1arc_v3.bil',
#  'n15_w083_1arc_v3.bil',
#  'n15_w084_1arc_v3.bil',
#  'n15_w085_1arc_v3.bil',
#  'n15_w086_1arc_v3.bil',
#  'n15_w087_1arc_v3.bil',
#  'n15_w088_1arc_v3.bil',
#  'n15_w089_1arc_v3.bil',
#  'n15_w090_1arc_v3.bil',
#  'n15_w091_1arc_v3.bil',
#  'n15_w092_1arc_v3.bil',
#  'n15_w093_1arc_v3.bil',
#  'n15_w094_1arc_v3.bil',
#  'n15_w096_1arc_v3.bil',
#  'n15_w097_1arc_v3.bil',
#  'n15_w098_1arc_v3.bil',
#  'n16_w062_1arc_v3.bil',
#  'n16_w063_1arc_v3.bil',
#  'n16_w089_1arc_v3.bil',
#  'n16_w090_1arc_v3.bil',
#  'n16_w091_1arc_v3.bil',
#  'n16_w092_1arc_v3.bil',
#  'n16_w093_1arc_v3.bil',
#  'n16_w094_1arc_v3.bil',
#  'n16_w095_1arc_v3.bil',
#  'n16_w096_1arc_v3.bil',
#  'n16_w097_1arc_v3.bil',
#  'n16_w098_1arc_v3.bil',
#  'n16_w099_1arc_v3.bil',
#  'n16_w100_1arc_v3.bil',
#  'n16_w101_1arc_v3.bil',
#  'n17_w062_1arc_v3.bil',
#  'n17_w063_1arc_v3.bil',
#  'n17_w064_1arc_v3.bil',
#  'n17_w065_1arc_v2.bil',
#  'n17_w065_1arc_v3.bil',
#  'n17_w066_1arc_v2.bil',
#  'n17_w066_1arc_v3.bil',
#  'n17_w067_1arc_v2.bil',
#  'n17_w067_1arc_v3.bil',
#  'n17_w068_1arc_v2.bil',
#  'n17_w068_1arc_v3.bil',
#  'n17_w072_1arc_v3.bil',
#  'n17_w076_1arc_v3.bil',
#  'n17_w088_1arc_v3.bil',
#  'n17_w089_1arc_v3.bil',
#  'n17_w090_1arc_v3.bil',
#  'n17_w091_1arc_v3.bil',
#  'n17_w092_1arc_v3.bil',
#  'n17_w093_1arc_v3.bil',
#  'n17_w094_1arc_v3.bil',
#  'n17_w095_1arc_v3.bil',
#  'n17_w096_1arc_v3.bil',
#  'n17_w097_1arc_v3.bil',
#  'n17_w098_1arc_v3.bil',
#  'n17_w099_1arc_v3.bil',
#  'n17_w100_1arc_v3.bil',
#  'n17_w101_1arc_v3.bil',
#  'n17_w102_1arc_v3.bil',
#  'n17_w103_1arc_v3.bil',
#  'n18_w065_1arc_v2.bil',
#  'n18_w066_1arc_v2.bil',
#  'n18_w067_1arc_v2.bil',
#  'n18_w068_1arc_v2.bil',
#  'n18_w076_1arc_v2.bil',
#  'n18_w088_1arc_v3.bil',
#  'n18_w089_1arc_v3.bil',
#  'n18_w090_1arc_v3.bil',
#  'n18_w091_1arc_v3.bil',
#  'n18_w092_1arc_v3.bil',
#  'n18_w093_1arc_v3.bil',
#  'n18_w094_1arc_v3.bil',
#  'n18_w095_1arc_v3.bil',
#  'n18_w096_1arc_v3.bil',
#  'n18_w097_1arc_v3.bil',
#  'n18_w098_1arc_v3.bil',
#  'n18_w099_1arc_v3.bil',
#  'n18_w100_1arc_v3.bil',
#  'n18_w101_1arc_v3.bil',
#  'n18_w102_1arc_v3.bil',
#  'n18_w103_1arc_v3.bil',
#  'n18_w104_1arc_v3.bil',
#  'n18_w105_1arc_v3.bil',
#  'n18_w156_1arc_v2.bil',
#  'n19_w088_1arc_v3.bil',
#  'n19_w089_1arc_v3.bil',
#  'n19_w090_1arc_v3.bil',
#  'n19_w091_1arc_v3.bil',
#  'n19_w092_1arc_v3.bil',
#  'n19_w096_1arc_v3.bil',
#  'n19_w097_1arc_v3.bil',
#  'n19_w098_1arc_v3.bil',
#  'n19_w099_1arc_v3.bil',
#  'n19_w100_1arc_v3.bil',
#  'n19_w101_1arc_v3.bil',
#  'n19_w102_1arc_v3.bil',
#  'n19_w103_1arc_v3.bil',
#  'n19_w104_1arc_v3.bil',
#  'n19_w105_1arc_v3.bil',
#  'n19_w106_1arc_v3.bil',
#  'n19_w155_1arc_v2.bil',
#  'n19_w156_1arc_v2.bil',
#  'n19_w157_1arc_v2.bil',
#  'n20_w087_1arc_v3.bil',
#  'n20_w088_1arc_v3.bil',
#  'n20_w089_1arc_v3.bil',
#  'n20_w090_1arc_v3.bil',
#  'n20_w091_1arc_v3.bil',
#  'n20_w097_1arc_v3.bil',
#  'n20_w098_1arc_v3.bil',
#  'n20_w099_1arc_v3.bil',
#  'n20_w100_1arc_v3.bil',
#  'n20_w101_1arc_v3.bil',
#  'n20_w102_1arc_v3.bil',
#  'n20_w103_1arc_v3.bil',
#  'n20_w104_1arc_v3.bil',
#  'n20_w105_1arc_v3.bil',
#  'n20_w106_1arc_v3.bil',
#  'n20_w156_1arc_v2.bil',
#  'n20_w157_1arc_v2.bil',
#  'n20_w158_1arc_v2.bil',
#  'n21_w087_1arc_v3.bil',
#  'n21_w088_1arc_v3.bil',
#  'n21_w089_1arc_v3.bil',
#  'n21_w090_1arc_v3.bil',
#  'n21_w091_1arc_v3.bil',
#  'n21_w098_1arc_v3.bil',
#  'n21_w099_1arc_v3.bil',
#  'n21_w100_1arc_v3.bil',
#  'n21_w101_1arc_v3.bil',
#  'n21_w102_1arc_v3.bil',
#  'n21_w103_1arc_v3.bil',
#  'n21_w104_1arc_v3.bil',
#  'n21_w105_1arc_v3.bil',
#  'n21_w106_1arc_v3.bil',
#  'n21_w107_1arc_v3.bil',
#  'n21_w157_1arc_v2.bil',
#  'n21_w158_1arc_v2.bil',
#  'n22_w098_1arc_v3.bil',
#  'n22_w099_1arc_v3.bil',
#  'n22_w100_1arc_v3.bil',
#  'n22_w101_1arc_v3.bil',
#  'n22_w102_1arc_v3.bil',
#  'n22_w103_1arc_v3.bil',
#  'n22_w104_1arc_v3.bil',
#  'n22_w105_1arc_v3.bil',
#  'n22_w106_1arc_v3.bil',
#  'n22_w107_1arc_v3.bil',
#  'n22_w110_1arc_v3.bil',
#  'n22_w111_1arc_v3.bil',
#  'n23_w098_1arc_v3.bil',
#  'n23_w099_1arc_v3.bil',
#  'n23_w100_1arc_v3.bil',
#  'n23_w101_1arc_v3.bil',
#  'n23_w102_1arc_v3.bil',
#  'n23_w103_1arc_v3.bil',
#  'n23_w104_1arc_v3.bil',
#  'n23_w105_1arc_v3.bil',
#  'n23_w106_1arc_v3.bil',
#  'n23_w107_1arc_v3.bil',
#  'n23_w108_1arc_v3.bil',
#  'n23_w110_1arc_v3.bil',
#  'n23_w111_1arc_v3.bil',
#  'n24_w081_1arc_v2.bil',
#  'n24_w082_1arc_v2.bil',
#  'n24_w083_1arc_v2.bil',
#  'n24_w098_1arc_v3.bil',
#  'n24_w099_1arc_v3.bil',
#  'n24_w100_1arc_v3.bil',
#  'n24_w101_1arc_v3.bil',
#  'n24_w102_1arc_v3.bil',
#  'n24_w103_1arc_v3.bil',
#  'n24_w104_1arc_v3.bil',
#  'n24_w105_1arc_v3.bil',
#  'n24_w106_1arc_v3.bil',
#  'n24_w107_1arc_v3.bil',
#  'n24_w108_1arc_v3.bil',
#  'n24_w109_1arc_v3.bil',
#  'n24_w110_1arc_v3.bil',
#  'n24_w111_1arc_v3.bil',
#  'n24_w112_1arc_v3.bil',
#  'n24_w113_1arc_v3.bil',
#  'n25_w081_1arc_v2.bil',
#  'n25_w082_1arc_v2.bil',
#  'n25_w098_1arc_v2.bil',
#  'n25_w098_1arc_v3.bil',
#  'n25_w099_1arc_v3.bil',
#  'n25_w100_1arc_v3.bil',
#  'n25_w101_1arc_v3.bil',
#  'n25_w102_1arc_v3.bil',
#  'n25_w103_1arc_v3.bil',
#  'n25_w104_1arc_v3.bil',
#  'n25_w105_1arc_v3.bil',
#  'n25_w106_1arc_v3.bil',
#  'n25_w107_1arc_v3.bil',
#  'n25_w108_1arc_v3.bil',
#  'n25_w109_1arc_v3.bil',
#  'n25_w110_1arc_v3.bil',
#  'n25_w111_1arc_v3.bil',
#  'n25_w112_1arc_v3.bil',
#  'n25_w113_1arc_v3.bil',
#  'n26_w081_1arc_v2.bil',
#  'n26_w082_1arc_v2.bil',
#  'n26_w083_1arc_v2.bil',
#  'n26_w098_1arc_v2.bil',
#  'n26_w098_1arc_v3.bil',
#  'n26_w099_1arc_v2.bil',
#  'n26_w099_1arc_v3.bil',
#  'n26_w100_1arc_v2.bil',
#  'n26_w100_1arc_v3.bil',
#  'n26_w101_1arc_v3.bil',
#  'n26_w102_1arc_v3.bil',
#  'n26_w103_1arc_v3.bil',
#  'n26_w104_1arc_v3.bil',
#  'n26_w105_1arc_v3.bil',
#  'n26_w106_1arc_v3.bil',
#  'n26_w107_1arc_v3.bil',
#  'n26_w108_1arc_v3.bil',
#  'n26_w109_1arc_v3.bil',
#  'n26_w110_1arc_v3.bil',
#  'n26_w112_1arc_v3.bil',
#  'n26_w113_1arc_v3.bil',
#  'n26_w114_1arc_v3.bil',
#  'n26_w115_1arc_v3.bil',
#  'n27_w081_1arc_v2.bil',
#  'n27_w082_1arc_v2.bil',
#  'n27_w083_1arc_v2.bil',
#  'n27_w097_1arc_v2.bil',
#  'n27_w098_1arc_v2.bil',
#  'n27_w099_1arc_v2.bil',
#  'n27_w100_1arc_v2.bil',
#  'n27_w100_1arc_v3.bil',
#  'n27_w101_1arc_v3.bil',
#  'n27_w102_1arc_v3.bil',
#  'n27_w103_1arc_v3.bil',
#  'n27_w104_1arc_v3.bil',
#  'n27_w105_1arc_v3.bil',
#  'n27_w106_1arc_v3.bil',
#  'n27_w107_1arc_v3.bil',
#  'n27_w108_1arc_v3.bil',
#  'n27_w109_1arc_v3.bil',
#  'n27_w110_1arc_v3.bil',
#  'n27_w111_1arc_v3.bil',
#  'n27_w112_1arc_v3.bil',
#  'n27_w113_1arc_v3.bil',
#  'n27_w114_1arc_v3.bil',
#  'n27_w115_1arc_v3.bil',
#  'n27_w116_1arc_v3.bil',
#  'n28_w081_1arc_v2.bil',
#  'n28_w082_1arc_v2.bil',
#  'n28_w083_1arc_v2.bil',
#  'n28_w090_1arc_v2.bil',
#  'n28_w096_1arc_v2.bil',
#  'n28_w097_1arc_v2.bil',
#  'n28_w098_1arc_v2.bil',
#  'n28_w099_1arc_v2.bil',
#  'n28_w100_1arc_v2.bil',
#  'n28_w101_1arc_v2.bil',
#  'n28_w101_1arc_v3.bil',
#  'n28_w102_1arc_v3.bil',
#  'n28_w103_1arc_v3.bil',
#  'n28_w104_1arc_v2.bil',
#  'n28_w104_1arc_v3.bil',
#  'n28_w105_1arc_v3.bil',
#  'n28_w106_1arc_v3.bil',
#  'n28_w107_1arc_v3.bil',
#  'n28_w108_1arc_v3.bil',
#  'n28_w109_1arc_v3.bil',
#  'n28_w110_1arc_v3.bil',
#  'n28_w111_1arc_v3.bil',
#  'n28_w112_1arc_v3.bil',
#  'n28_w113_1arc_v3.bil',
#  'n28_w114_1arc_v3.bil',
#  'n28_w115_1arc_v3.bil',
#  'n28_w116_1arc_v3.bil',
#  'n29_w081_1arc_v2.bil',
#  'n29_w082_1arc_v2.bil',
#  'n29_w083_1arc_v2.bil',
#  'n29_w084_1arc_v2.bil',
#  'n29_w085_1arc_v2.bil',
#  'n29_w086_1arc_v2.bil',
#  'n29_w089_1arc_v2.bil',
#  'n29_w090_1arc_v2.bil',
#  'n29_w091_1arc_v2.bil',
#  'n29_w092_1arc_v2.bil',
#  'n29_w093_1arc_v2.bil',
#  'n29_w094_1arc_v2.bil',
#  'n29_w095_1arc_v2.bil',
#  'n29_w096_1arc_v2.bil',
#  'n29_w097_1arc_v2.bil',
#  'n29_w098_1arc_v2.bil',
#  'n29_w099_1arc_v2.bil',
#  'n29_w100_1arc_v2.bil',
#  'n29_w101_1arc_v2.bil',
#  'n29_w102_1arc_v2.bil',
#  'n29_w103_1arc_v2.bil',
#  'n29_w104_1arc_v2.bil',
#  'n29_w104_1arc_v3.bil',
#  'n29_w105_1arc_v2.bil',
#  'n29_w105_1arc_v3.bil',
#  'n29_w106_1arc_v3.bil',
#  'n29_w107_1arc_v3.bil',
#  'n29_w108_1arc_v3.bil',
#  'n29_w109_1arc_v3.bil',
#  'n29_w110_1arc_v3.bil',
#  'n29_w111_1arc_v3.bil',
#  'n29_w112_1arc_v3.bil',
#  'n29_w113_1arc_v3.bil',
#  'n29_w114_1arc_v3.bil',
#  'n29_w115_1arc_v3.bil',
#  'n29_w116_1arc_v3.bil',
#  'n30_w082_1arc_v2.bil',
#  'n30_w083_1arc_v2.bil',
#  'n30_w084_1arc_v2.bil',
#  'n30_w085_1arc_v2.bil',
#  'n30_w086_1arc_v2.bil',
#  'n30_w087_1arc_v2.bil',
#  'n30_w088_1arc_v2.bil',
#  'n30_w089_1arc_v2.bil',
#  'n30_w090_1arc_v2.bil',
#  'n30_w091_1arc_v2.bil',
#  'n30_w092_1arc_v2.bil',
#  'n30_w093_1arc_v2.bil',
#  'n30_w094_1arc_v2.bil',
#  'n30_w095_1arc_v2.bil',
#  'n30_w096_1arc_v2.bil',
#  'n30_w097_1arc_v2.bil',
#  'n30_w098_1arc_v2.bil',
#  'n30_w099_1arc_v2.bil',
#  'n30_w100_1arc_v2.bil',
#  'n30_w101_1arc_v2.bil',
#  'n30_w102_1arc_v2.bil',
#  'n30_w103_1arc_v2.bil',
#  'n30_w104_1arc_v2.bil',
#  'n30_w105_1arc_v2.bil',
#  'n30_w105_1arc_v3.bil',
#  'n30_w106_1arc_v2.bil',
#  'n30_w106_1arc_v3.bil',
#  'n30_w107_1arc_v3.bil',
#  'n30_w108_1arc_v3.bil',
#  'n30_w109_1arc_v3.bil',
#  'n30_w110_1arc_v3.bil',
#  'n30_w111_1arc_v3.bil',
#  'n30_w112_1arc_v3.bil',
#  'n30_w113_1arc_v3.bil',
#  'n30_w114_1arc_v3.bil',
#  'n30_w115_1arc_v3.bil',
#  'n30_w116_1arc_v3.bil',
#  'n30_w117_1arc_v3.bil',
#  'n31_w081_1arc_v2.bil',
#  'n31_w082_1arc_v2.bil',
#  'n31_w083_1arc_v2.bil',
#  'n31_w084_1arc_v2.bil',
#  'n31_w085_1arc_v2.bil',
#  'n31_w086_1arc_v2.bil',
#  'n31_w087_1arc_v2.bil',
#  'n31_w088_1arc_v2.bil',
#  'n31_w089_1arc_v2.bil',
#  'n31_w090_1arc_v2.bil',
#  'n31_w091_1arc_v2.bil',
#  'n31_w092_1arc_v2.bil',
#  'n31_w093_1arc_v2.bil',
#  'n31_w094_1arc_v2.bil',
#  'n31_w095_1arc_v2.bil',
#  'n31_w096_1arc_v2.bil',
#  'n31_w097_1arc_v2.bil',
#  'n31_w098_1arc_v2.bil',
#  'n31_w099_1arc_v2.bil',
#  'n31_w100_1arc_v2.bil',
#  'n31_w101_1arc_v2.bil',
#  'n31_w102_1arc_v2.bil',
#  'n31_w103_1arc_v2.bil',
#  'n31_w104_1arc_v2.bil',
#  'n31_w105_1arc_v2.bil',
#  'n31_w106_1arc_v2.bil',
#  'n31_w107_1arc_v2.bil',
#  'n31_w107_1arc_v3.bil',
#  'n31_w108_1arc_v2.bil',
#  'n31_w108_1arc_v3.bil',
#  'n31_w109_1arc_v2.bil',
#  'n31_w109_1arc_v3.bil',
#  'n31_w110_1arc_v2.bil',
#  'n31_w110_1arc_v3.bil',
#  'n31_w111_1arc_v2.bil',
#  'n31_w111_1arc_v3.bil',
#  'n31_w112_1arc_v2.bil',
#  'n31_w112_1arc_v3.bil',
#  'n31_w113_1arc_v2.bil',
#  'n31_w113_1arc_v3.bil',
#  'n31_w114_1arc_v2.bil',
#  'n31_w114_1arc_v3.bil',
#  'n31_w115_1arc_v3.bil',
#  'n31_w116_1arc_v3.bil',
#  'n31_w117_1arc_v3.bil',
#  'n32_w080_1arc_v2.bil',
#  'n32_w081_1arc_v2.bil',
#  'n32_w082_1arc_v2.bil',
#  'n32_w083_1arc_v2.bil',
#  'n32_w084_1arc_v2.bil',
#  'n32_w085_1arc_v2.bil',
#  'n32_w086_1arc_v2.bil',
#  'n32_w087_1arc_v2.bil',
#  'n32_w088_1arc_v2.bil',
#  'n32_w089_1arc_v2.bil',
#  'n32_w090_1arc_v2.bil',
#  'n32_w091_1arc_v2.bil',
#  'n32_w092_1arc_v2.bil',
#  'n32_w093_1arc_v2.bil',
#  'n32_w094_1arc_v2.bil',
#  'n32_w095_1arc_v2.bil',
#  'n32_w096_1arc_v2.bil',
#  'n32_w097_1arc_v2.bil',
#  'n32_w098_1arc_v2.bil',
#  'n32_w099_1arc_v2.bil',
#  'n32_w100_1arc_v2.bil',
#  'n32_w101_1arc_v2.bil',
#  'n32_w102_1arc_v2.bil',
#  'n32_w103_1arc_v2.bil',
#  'n32_w104_1arc_v2.bil',
#  'n32_w105_1arc_v2.bil',
#  'n32_w106_1arc_v2.bil',
#  'n32_w107_1arc_v2.bil',
#  'n32_w108_1arc_v2.bil',
#  'n32_w109_1arc_v2.bil',
#  'n32_w110_1arc_v2.bil',
#  'n32_w111_1arc_v2.bil',
#  'n32_w112_1arc_v2.bil',
#  'n32_w113_1arc_v2.bil',
#  'n32_w114_1arc_v2.bil',
#  'n32_w115_1arc_v2.bil',
#  'n32_w116_1arc_v2.bil',
#  'n32_w116_1arc_v3.bil',
#  'n32_w117_1arc_v2.bil',
#  'n32_w117_1arc_v3.bil',
#  'n32_w118_1arc_v2.bil',
#  'n32_w119_1arc_v2.bil',
#  'n33_w078_1arc_v2.bil',
#  'n33_w079_1arc_v2.bil',
#  'n33_w080_1arc_v2.bil',
#  'n33_w081_1arc_v2.bil',
#  'n33_w082_1arc_v2.bil',
#  'n33_w083_1arc_v2.bil',
#  'n33_w084_1arc_v2.bil',
#  'n33_w085_1arc_v2.bil',
#  'n33_w086_1arc_v2.bil',
#  'n33_w087_1arc_v2.bil',
#  'n33_w088_1arc_v2.bil',
#  'n33_w089_1arc_v2.bil',
#  'n33_w090_1arc_v2.bil',
#  'n33_w091_1arc_v2.bil',
#  'n33_w092_1arc_v2.bil',
#  'n33_w093_1arc_v2.bil',
#  'n33_w094_1arc_v2.bil',
#  'n33_w095_1arc_v2.bil',
#  'n33_w096_1arc_v2.bil',
#  'n33_w097_1arc_v2.bil',
#  'n33_w098_1arc_v2.bil',
#  'n33_w099_1arc_v2.bil',
#  'n33_w100_1arc_v2.bil',
#  'n33_w101_1arc_v2.bil',
#  'n33_w102_1arc_v2.bil',
#  'n33_w103_1arc_v2.bil',
#  'n33_w104_1arc_v2.bil',
#  'n33_w105_1arc_v2.bil',
#  'n33_w106_1arc_v2.bil',
#  'n33_w107_1arc_v2.bil',
#  'n33_w108_1arc_v2.bil',
#  'n33_w109_1arc_v2.bil',
#  'n33_w110_1arc_v2.bil',
#  'n33_w111_1arc_v2.bil',
#  'n33_w112_1arc_v2.bil',
#  'n33_w113_1arc_v2.bil',
#  'n33_w114_1arc_v2.bil',
#  'n33_w115_1arc_v2.bil',
#  'n33_w116_1arc_v2.bil',
#  'n33_w117_1arc_v2.bil',
#  'n33_w118_1arc_v2.bil',
#  'n33_w119_1arc_v2.bil',
#  'n33_w120_1arc_v2.bil',
#  'n33_w121_1arc_v2.bil',
#  'n34_w077_1arc_v2.bil',
#  'n34_w078_1arc_v2.bil',
#  'n34_w079_1arc_v2.bil',
#  'n34_w080_1arc_v2.bil',
#  'n34_w081_1arc_v2.bil',
#  'n34_w082_1arc_v2.bil',
#  'n34_w083_1arc_v2.bil',
#  'n34_w084_1arc_v2.bil',
#  'n34_w085_1arc_v2.bil',
#  'n34_w086_1arc_v2.bil',
#  'n34_w087_1arc_v2.bil',
#  'n34_w088_1arc_v2.bil',
#  'n34_w089_1arc_v2.bil',
#  'n34_w090_1arc_v2.bil',
#  'n34_w091_1arc_v2.bil',
#  'n34_w092_1arc_v2.bil',
#  'n34_w093_1arc_v2.bil',
#  'n34_w094_1arc_v2.bil',
#  'n34_w095_1arc_v2.bil',
#  'n34_w096_1arc_v2.bil',
#  'n34_w097_1arc_v2.bil',
#  'n34_w098_1arc_v2.bil',
#  'n34_w099_1arc_v2.bil',
#  'n34_w100_1arc_v2.bil',
#  'n34_w101_1arc_v2.bil',
#  'n34_w102_1arc_v2.bil',
#  'n34_w103_1arc_v2.bil',
#  'n34_w104_1arc_v2.bil',
#  'n34_w105_1arc_v2.bil',
#  'n34_w106_1arc_v2.bil',
#  'n34_w107_1arc_v2.bil',
#  'n34_w108_1arc_v2.bil',
#  'n34_w109_1arc_v2.bil',
#  'n34_w110_1arc_v2.bil',
#  'n34_w111_1arc_v2.bil',
#  'n34_w112_1arc_v2.bil',
#  'n34_w113_1arc_v2.bil',
#  'n34_w114_1arc_v2.bil',
#  'n34_w115_1arc_v2.bil',
#  'n34_w116_1arc_v2.bil',
#  'n34_w117_1arc_v2.bil',
#  'n34_w118_1arc_v2.bil',
#  'n34_w119_1arc_v2.bil',
#  'n34_w120_1arc_v2.bil',
#  'n34_w121_1arc_v2.bil',
#  'n35_w076_1arc_v2.bil',
#  'n35_w077_1arc_v2.bil',
#  'n35_w078_1arc_v2.bil',
#  'n35_w079_1arc_v2.bil',
#  'n35_w080_1arc_v2.bil',
#  'n35_w081_1arc_v2.bil',
#  'n35_w082_1arc_v2.bil',
#  'n35_w083_1arc_v2.bil',
#  'n35_w084_1arc_v2.bil',
#  'n35_w085_1arc_v2.bil',
#  'n35_w086_1arc_v2.bil',
#  'n35_w087_1arc_v2.bil',
#  'n35_w088_1arc_v2.bil',
#  'n35_w089_1arc_v2.bil',
#  'n35_w090_1arc_v2.bil',
#  'n35_w091_1arc_v2.bil',
#  'n35_w092_1arc_v2.bil',
#  'n35_w093_1arc_v2.bil',
#  'n35_w094_1arc_v2.bil',
#  'n35_w095_1arc_v2.bil',
#  'n35_w096_1arc_v2.bil',
#  'n35_w097_1arc_v2.bil',
#  'n35_w098_1arc_v2.bil',
#  'n35_w099_1arc_v2.bil',
#  'n35_w100_1arc_v2.bil',
#  'n35_w101_1arc_v2.bil',
#  'n35_w102_1arc_v2.bil',
#  'n35_w103_1arc_v2.bil',
#  'n35_w104_1arc_v2.bil',
#  'n35_w105_1arc_v2.bil',
#  'n35_w106_1arc_v2.bil',
#  'n35_w107_1arc_v2.bil',
#  'n35_w108_1arc_v2.bil',
#  'n35_w109_1arc_v2.bil',
#  'n35_w110_1arc_v2.bil',
#  'n35_w111_1arc_v2.bil',
#  'n35_w112_1arc_v2.bil',
#  'n35_w113_1arc_v2.bil',
#  'n35_w114_1arc_v2.bil',
#  'n35_w115_1arc_v2.bil',
#  'n35_w116_1arc_v2.bil',
#  'n35_w117_1arc_v2.bil',
#  'n35_w118_1arc_v2.bil',
#  'n35_w119_1arc_v2.bil',
#  'n35_w120_1arc_v2.bil',
#  'n35_w121_1arc_v2.bil',
#  'n35_w122_1arc_v2.bil',
#  'n36_w076_1arc_v2.bil',
#  'n36_w077_1arc_v2.bil',
#  'n36_w078_1arc_v2.bil',
#  'n36_w079_1arc_v2.bil',
#  'n36_w080_1arc_v2.bil',
#  'n36_w081_1arc_v2.bil',
#  'n36_w082_1arc_v2.bil',
#  'n36_w083_1arc_v2.bil',
#  'n36_w084_1arc_v2.bil',
#  'n36_w085_1arc_v2.bil',
#  'n36_w086_1arc_v2.bil',
#  'n36_w087_1arc_v2.bil',
#  'n36_w088_1arc_v2.bil',
#  'n36_w089_1arc_v2.bil',
#  'n36_w090_1arc_v2.bil',
#  'n36_w091_1arc_v2.bil',
#  'n36_w092_1arc_v2.bil',
#  'n36_w093_1arc_v2.bil',
#  'n36_w094_1arc_v2.bil',
#  'n36_w095_1arc_v2.bil',
#  'n36_w096_1arc_v2.bil',
#  'n36_w097_1arc_v2.bil',
#  'n36_w098_1arc_v2.bil',
#  'n36_w099_1arc_v2.bil',
#  'n36_w100_1arc_v2.bil',
#  'n36_w101_1arc_v2.bil',
#  'n36_w102_1arc_v2.bil',
#  'n36_w103_1arc_v2.bil',
#  'n36_w104_1arc_v2.bil',
#  'n36_w105_1arc_v2.bil',
#  'n36_w106_1arc_v2.bil',
#  'n36_w107_1arc_v2.bil',
#  'n36_w108_1arc_v2.bil',
#  'n36_w109_1arc_v2.bil',
#  'n36_w110_1arc_v2.bil',
#  'n36_w111_1arc_v2.bil',
#  'n36_w112_1arc_v2.bil',
#  'n36_w113_1arc_v2.bil',
#  'n36_w114_1arc_v2.bil',
#  'n36_w115_1arc_v2.bil',
#  'n36_w116_1arc_v2.bil',
#  'n36_w117_1arc_v2.bil',
#  'n36_w118_1arc_v2.bil',
#  'n36_w119_1arc_v2.bil',
#  'n36_w120_1arc_v2.bil',
#  'n36_w121_1arc_v2.bil',
#  'n36_w122_1arc_v2.bil',
#  'n36_w123_1arc_v2.bil',
#  'n37_w076_1arc_v2.bil',
#  'n37_w077_1arc_v2.bil',
#  'n37_w078_1arc_v2.bil',
#  'n37_w079_1arc_v2.bil',
#  'n37_w080_1arc_v2.bil',
#  'n37_w081_1arc_v2.bil',
#  'n37_w082_1arc_v2.bil',
#  'n37_w083_1arc_v2.bil',
#  'n37_w084_1arc_v2.bil',
#  'n37_w085_1arc_v2.bil',
#  'n37_w086_1arc_v2.bil',
#  'n37_w087_1arc_v2.bil',
#  'n37_w088_1arc_v2.bil',
#  'n37_w089_1arc_v2.bil',
#  'n37_w090_1arc_v2.bil',
#  'n37_w091_1arc_v2.bil',
#  'n37_w092_1arc_v2.bil',
#  'n37_w093_1arc_v2.bil',
#  'n37_w094_1arc_v2.bil',
#  'n37_w095_1arc_v2.bil',
#  'n37_w096_1arc_v2.bil',
#  'n37_w097_1arc_v2.bil',
#  'n37_w098_1arc_v2.bil',
#  'n37_w099_1arc_v2.bil',
#  'n37_w100_1arc_v2.bil',
#  'n37_w101_1arc_v2.bil',
#  'n37_w102_1arc_v2.bil',
#  'n37_w103_1arc_v2.bil',
#  'n37_w104_1arc_v2.bil',
#  'n37_w105_1arc_v2.bil',
#  'n37_w106_1arc_v2.bil',
#  'n37_w107_1arc_v2.bil',
#  ...]

# %%
's18_w073_1arc_v3_bil' in file_list
# Out:
# False
